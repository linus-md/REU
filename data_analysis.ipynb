# %%
# Import Libraries
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import Data (Insert your path here)
path = '/Users/las/Documents/GitHub/REU/data_136_2.csv'
df = pd.read_csv(path)
df.B.hist(bins=136)
# Out:
# <AxesSubplot:>

# %%
data = []
for i in range(0, 137, 2):
    if i in set(2*round(df.B/2)):
        data.append(i)
print(data)
# Out:
# [32, 48, 72, 74, 78, 80, 128, 130, 132, 134, 136]
