# %%
# Import Libraries
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import Data A (Insert your path here)
path = '/Users/las/Documents/GitHub/REU/Data/data_A.csv'
df_A = pd.read_csv(path)
path = '/Users/las/Documents/GitHub/REU/Data/data_B.csv'
df_B = pd.read_csv(path)

# %%
df_A.no = [val if val %2 == 0 else val+1 for val in df_A.no]
df_B.no = [val if val %2 == 0 else val+1 for val in df_B.no]
dist_A = [len(df_A[df_A.no == i]) for i in range(0, 185)]
dist_B = [len(df_B[df_B.no == i]) for i in range(0, 185)]

sols = df_A.no.append(df_B.no)
sols = list(sols)
tmp = set([i if i not in sols else 0 for i in range(0,186, 2)])
print(sorted(tmp))
# Out:
# [0, 92, 94, 96, 98, 100, 102, 104, 106, 108, 110, 112, 114, 116, 118, 120, 122, 124, 126, 128, 130, 132, 134, 136, 138, 140, 142, 144, 146, 148, 150, 152, 154, 156, 158, 160, 162, 164, 166, 168, 170, 172, 174, 176, 178, 180, 182, 184]

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(0, 185), dist_A, width=1.5, label="Hill climbing data")
ax.set_ylabel('Number of instances')
ax.set_xlabel('Number of real solutions')
ax.set_xticks([i*20 for i in range(9)] + [184])
ax.set_ylim([0, 12500])
ax.legend()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(range(0, 185), dist_B, width=1.5, label="Random data")
ax.set_ylabel('Number of instances')
ax.set_xlabel('Number of real solutions')
ax.set_xticks([i*20 for i in range(9)] + [184])
ax.set_ylim([0, 12500])

ax.legend()
